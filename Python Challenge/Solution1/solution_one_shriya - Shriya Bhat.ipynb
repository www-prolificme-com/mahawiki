# %%
n=input("enter the number of elements : ")
n=int(n)
e=0
ans=0
#def logical_xor(str1, str2):
    #return bool(str1) ^ bool(str2)
  
def xor(x,y):  
    return ((x | y) & (~x | ~y))
      
print("enter the elements")
for i in range(0,n):
   e=int(input())
   ans = int(xor(ans, e))


print(str(ans)+" is not repeated twice")
# Out:
# enter the number of elements : 7
# enter the elements
# 2
# 4
# 5
# 2
# 6
# 4
# 5
# 6 is not repeated twice
